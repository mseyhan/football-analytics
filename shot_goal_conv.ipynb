# %%
# %run vizFunc.py

# database path
db_path = config.get('statsbomb_db_path')

# create an sqlalchemy engine to connect to the SQLite database
engine = create_engine(f'sqlite:///{db_path}')

# instantiate a parser object
parser = Sbopen()

# %%
# RUN ONLY WHEN WORKING A DIFFERENT PLAYER/SEASON
# connect to the sqlite database
conn = sqlite3.connect(db_path)

with open('data/selected_matches.sql') as inserts:
    q1 = inserts.read()

# retrieve all matchdata
seasonId = 27 # only for reporting, change in .sql file
competitionId = 2
query = q1
print(query)
# use the connection and query to create a dataframe
matches = pd.read_sql_query(query, conn)

# close the connection
conn.close()
# Out:
# /* Retrieve all matches and lineups for the target season*/
# SELECT m.*
# 	, l. player_id
# 	, l.player_name
# 	, l.player_nickname
# 	, l.jersey_number
# 	, l.team_id
# 	, l.team_name
# 	, l.country_id
# 	, l.country_name as country_name_lineup
# FROM (
# 	SELECT *
# 	FROM MATCH m
# 	WHERE 1=1
# 	AND  season_id = 27
# 	AND competition_id = 2 -- if it's necessary to see the picture regardless the competition through the season, just comment out.
# 	)  m
# LEFT JOIN lineup l
# ON m.match_id = l.match_id

# %% [markdown]
# ## Scope of the analysis: 2014-2015 Barcelona, all matches that Lionel Messi played.
# ---

# %%
# RUN ONLY WHEN WORKING A DIFFERENT PLAYER/SEASON
matches.head()
match_list = matches.match_id.unique().tolist()

# %%
# %%time 
# RUN ONLY WHEN WORKING A DIFFERENT PLAYER-SEASON
event_df_list = []
for i, match in enumerate(match_list):
    print(f"{i} - ENTERED :",match)
    event_df_list.append(parser.event(match)[0])
    print("event appended\n---------------------")
print("appending complete")

df_event = pd.concat(event_df_list)
print("Concatenation done")

# in order not to do the same data retrieval over and over, using the to_sql function to write the dataframe to the sqlite database
df_event.to_sql('event_stg', engine, if_exists='replace', index=False)
# Out:
# 0 - ENTERED : 3754058
# event appended
# ---------------------
# 1 - ENTERED : 3754245
# event appended
# ---------------------
# 2 - ENTERED : 3754136
# event appended
# ---------------------
# 3 - ENTERED : 3754037
# event appended
# ---------------------
# 4 - ENTERED : 3754039
# event appended
# ---------------------
# 5 - ENTERED : 3754041
# event appended
# ---------------------
# 6 - ENTERED : 3754042
# event appended
# ---------------------
# 7 - ENTERED : 3754043
# event appended
# ---------------------
# 8 - ENTERED : 3754045
# event appended
# ---------------------
# 9 - ENTERED : 3754048
# event appended
# ---------------------
# 10 - ENTERED : 3754049
# event appended
# ---------------------
# 11 - ENTERED : 3754050
# event appended
# ---------------------
# 12 - ENTERED : 3754052
# event appended
# ---------------------
# 13 - ENTERED : 3754053
# event appended
# ---------------------
# 14 - ENTERED : 3754055
# event appended
# ---------------------
# 15 - ENTERED : 3754226
# event appended
# ---------------------
# 16 - ENTERED : 3754014
# event appended
# ---------------------
# 17 - ENTERED : 3754091
# event appended
# ---------------------
# 18 - ENTERED : 3754135
# event appended
# ---------------------
# 19 - ENTERED : 3754293
# event appended
# ---------------------
# 20 - ENTERED : 3754339
# event appended
# ---------------------
# 21 - ENTERED : 3754146
# event appended
# ---------------------
# 22 - ENTERED : 3754347
# event appended
# ---------------------
# 23 - ENTERED : 3754255
# event appended
# ---------------------
# 24 - ENTERED : 3754278
# event appended
# ---------------------
# 25 - ENTERED : 3753979
# event appended
# ---------------------
# 26 - ENTERED : 3753972
# event appended
# ---------------------
# 27 - ENTERED : 3753978
# event appended
# ---------------------
# 28 - ENTERED : 3753974
# event appended
# ---------------------
# 29 - ENTERED : 3753993
# event appended
# ---------------------
# 30 - ENTERED : 3753983
# event appended
# ---------------------
# 31 - ENTERED : 3754015
# event appended
# ---------------------
# 32 - ENTERED : 3754038
# event appended
# ---------------------
# 33 - ENTERED : 3754001
# event appended
# ---------------------
# 34 - ENTERED : 3754007
# event appended
# ---------------------
# 35 - ENTERED : 3754008
# event appended
# ---------------------
# 36 - ENTERED : 3754029
# event appended
# ---------------------
# 37 - ENTERED : 3753995
# event appended
# ---------------------
# 38 - ENTERED : 3753999
# event appended
# ---------------------
# 39 - ENTERED : 3754017
# event appended
# ---------------------
# 40 - ENTERED : 3754006
# event appended
# ---------------------
# 41 - ENTERED : 3754023
# event appended
# ---------------------
# 42 - ENTERED : 3753984
# event appended
# ---------------------
# 43 - ENTERED : 3754011
# event appended
# ---------------------
# 44 - ENTERED : 3754010
# event appended
# ---------------------
# 45 - ENTERED : 3754028
# event appended
# ---------------------
# 46 - ENTERED : 3753996
# event appended
# ---------------------
# 47 - ENTERED : 3754025
# event appended
# ---------------------
# 48 - ENTERED : 3754068
# event appended
# ---------------------
# 49 - ENTERED : 3754056
# event appended
# ---------------------
# 50 - ENTERED : 3754040
# event appended
# ---------------------
# 51 - ENTERED : 3754074
# event appended
# ---------------------
# 52 - ENTERED : 3754076
# event appended
# ---------------------
# 53 - ENTERED : 3754067
# event appended
# ---------------------
# 54 - ENTERED : 3754079
# event appended
# ---------------------
# 55 - ENTERED : 3754090
# event appended
# ---------------------
# 56 - ENTERED : 3754083
# event appended
# ---------------------
# 57 - ENTERED : 3754077
# event appended
# ---------------------
# 58 - ENTERED : 3754060
# event appended
# ---------------------
# 59 - ENTERED : 3754073
# event appended
# ---------------------
# 60 - ENTERED : 3754085
# event appended
# ---------------------
# 61 - ENTERED : 3754047
# event appended
# ---------------------
# 62 - ENTERED : 3754051
# event appended
# ---------------------
# 63 - ENTERED : 3754093
# event appended
# ---------------------
# 64 - ENTERED : 3754046
# event appended
# ---------------------
# 65 - ENTERED : 3754072
# event appended
# ---------------------
# 66 - ENTERED : 3754082
# event appended
# ---------------------
# 67 - ENTERED : 3754106
# event appended
# ---------------------
# 68 - ENTERED : 3754099
# event appended
# ---------------------
# 69 - ENTERED : 3754098
# event appended
# ---------------------
# 70 - ENTERED : 3754057
# event appended
# ---------------------
# 71 - ENTERED : 3754112
# event appended
# ---------------------
# 72 - ENTERED : 3754117
# event appended
# ---------------------
# 73 - ENTERED : 3754104
# event appended
# ---------------------
# 74 - ENTERED : 3754054
# event appended
# ---------------------
# 75 - ENTERED : 3754113
# event appended
# ---------------------
# 76 - ENTERED : 3754107
# event appended
# ---------------------
# 77 - ENTERED : 3754105
# event appended
# ---------------------
# 78 - ENTERED : 3754097
# event appended
# ---------------------
# 79 - ENTERED : 3754102
# event appended
# ---------------------
# 80 - ENTERED : 3754115
# event appended
# ---------------------
# 81 - ENTERED : 3754148
# event appended
# ---------------------
# 82 - ENTERED : 3754169
# event appended
# ---------------------
# 83 - ENTERED : 3754174
# event appended
# ---------------------
# 84 - ENTERED : 3754185
# event appended
# ---------------------
# 85 - ENTERED : 3754162
# event appended
# ---------------------
# 86 - ENTERED : 3754096
# event appended
# ---------------------
# 87 - ENTERED : 3754171
# event appended
# ---------------------
# 88 - ENTERED : 3754119
# event appended
# ---------------------
# 89 - ENTERED : 3754126
# event appended
# ---------------------
# 90 - ENTERED : 3754133
# event appended
# ---------------------
# 91 - ENTERED : 3754167
# event appended
# ---------------------
# 92 - ENTERED : 3754145
# event appended
# ---------------------
# 93 - ENTERED : 3754153
# event appended
# ---------------------
# 94 - ENTERED : 3754143
# event appended
# ---------------------
# 95 - ENTERED : 3754186
# event appended
# ---------------------
# 96 - ENTERED : 3754130
# event appended
# ---------------------
# 97 - ENTERED : 3754188
# event appended
# ---------------------
# 98 - ENTERED : 3754178
# event appended
# ---------------------
# 99 - ENTERED : 3754157
# event appended
# ---------------------
# 100 - ENTERED : 3754166
# event appended
# ---------------------
# 101 - ENTERED : 3754211
# event appended
# ---------------------
# 102 - ENTERED : 3754150
# event appended
# ---------------------
# 103 - ENTERED : 3754160
# event appended
# ---------------------
# 104 - ENTERED : 3754218
# event appended
# ---------------------
# 105 - ENTERED : 3754217
# event appended
# ---------------------
# 106 - ENTERED : 3754205
# event appended
# ---------------------
# 107 - ENTERED : 3754221
# event appended
# ---------------------
# 108 - ENTERED : 3754198
# event appended
# ---------------------
# 109 - ENTERED : 3754193
# event appended
# ---------------------
# 110 - ENTERED : 3754222
# event appended
# ---------------------
# 111 - ENTERED : 3754213
# event appended
# ---------------------
# 112 - ENTERED : 3754212
# event appended
# ---------------------
# 113 - ENTERED : 3754223
# event appended
# ---------------------
# 114 - ENTERED : 3754197
# event appended
# ---------------------
# 115 - ENTERED : 3754208
# event appended
# ---------------------
# 116 - ENTERED : 3754204
# event appended
# ---------------------
# 117 - ENTERED : 3754194
# event appended
# ---------------------
# 118 - ENTERED : 3754219
# event appended
# ---------------------
# 119 - ENTERED : 3754254
# event appended
# ---------------------
# 120 - ENTERED : 3754230
# event appended
# ---------------------
# 121 - ENTERED : 3754285
# event appended
# ---------------------
# 122 - ENTERED : 3754233
# event appended
# ---------------------
# 123 - ENTERED : 3754270
# event appended
# ---------------------
# 124 - ENTERED : 3754237
# event appended
# ---------------------
# 125 - ENTERED : 3754257
# event appended
# ---------------------
# 126 - ENTERED : 3754266
# event appended
# ---------------------
# 127 - ENTERED : 3754256
# event appended
# ---------------------
# 128 - ENTERED : 3754288
# event appended
# ---------------------
# 129 - ENTERED : 3754238
# event appended
# ---------------------
# 130 - ENTERED : 3754269
# event appended
# ---------------------
# 131 - ENTERED : 3754234
# event appended
# ---------------------
# 132 - ENTERED : 3754246
# event appended
# ---------------------
# 133 - ENTERED : 3754296
# event appended
# ---------------------
# 134 - ENTERED : 3754273
# event appended
# ---------------------
# 135 - ENTERED : 3754263
# event appended
# ---------------------
# 136 - ENTERED : 3754268
# event appended
# ---------------------
# 137 - ENTERED : 3754286
# event appended
# ---------------------
# 138 - ENTERED : 3754291
# event appended
# ---------------------
# 139 - ENTERED : 3754283
# event appended
# ---------------------
# 140 - ENTERED : 3754235
# event appended
# ---------------------
# 141 - ENTERED : 3754279
# event appended
# ---------------------
# 142 - ENTERED : 3754276
# event appended
# ---------------------
# 143 - ENTERED : 3754287
# event appended
# ---------------------
# 144 - ENTERED : 3754259
# event appended
# ---------------------
# 145 - ENTERED : 3754335
# event appended
# ---------------------
# 146 - ENTERED : 3754298
# event appended
# ---------------------
# 147 - ENTERED : 3754315
# event appended
# ---------------------
# 148 - ENTERED : 3754330
# event appended
# ---------------------
# 149 - ENTERED : 3754337
# event appended
# ---------------------
# 150 - ENTERED : 3754297
# event appended
# ---------------------
# 151 - ENTERED : 3754301
# event appended
# ---------------------
# 152 - ENTERED : 3754323
# event appended
# ---------------------
# 153 - ENTERED : 3754304
# event appended
# ---------------------
# 154 - ENTERED : 3754311
# event appended
# ---------------------
# 155 - ENTERED : 3754328
# event appended
# ---------------------
# 156 - ENTERED : 3754309
# event appended
# ---------------------
# 157 - ENTERED : 3754325
# event appended
# ---------------------
# 158 - ENTERED : 3754329
# event appended
# ---------------------
# 159 - ENTERED : 3754302
# event appended
# ---------------------
# 160 - ENTERED : 3754013
# event appended
# ---------------------
# 161 - ENTERED : 3754044
# event appended
# ---------------------
# 162 - ENTERED : 3754351
# event appended
# ---------------------
# 163 - ENTERED : 3754343
# event appended
# ---------------------
# 164 - ENTERED : 3754109
# event appended
# ---------------------
# 165 - ENTERED : 3754182
# event appended
# ---------------------
# 166 - ENTERED : 3754240
# event appended
# ---------------------
# 167 - ENTERED : 3754336
# event appended
# ---------------------
# 168 - ENTERED : 3754247
# event appended
# ---------------------
# 169 - ENTERED : 3754156
# event appended
# ---------------------
# 170 - ENTERED : 3754265
# event appended
# ---------------------
# 171 - ENTERED : 3754000
# event appended
# ---------------------
# 172 - ENTERED : 3754003
# event appended
# ---------------------
# 173 - ENTERED : 3754344
# event appended
# ---------------------
# 174 - ENTERED : 3754131
# event appended
# ---------------------
# 175 - ENTERED : 3754300
# event appended
# ---------------------
# 176 - ENTERED : 3754312
# event appended
# ---------------------
# 177 - ENTERED : 3754138
# event appended
# ---------------------
# 178 - ENTERED : 3754203
# event appended
# ---------------------
# 179 - ENTERED : 3754190
# event appended
# ---------------------
# 180 - ENTERED : 3754066
# event appended
# ---------------------
# 181 - ENTERED : 3754034
# event appended
# ---------------------
# 182 - ENTERED : 3753985
# event appended
# ---------------------
# 183 - ENTERED : 3753987
# event appended
# ---------------------
# 184 - ENTERED : 3754189
# event appended
# ---------------------
# 185 - ENTERED : 3754129
# event appended
# ---------------------
# 186 - ENTERED : 3754180
# event appended
# ---------------------
# 187 - ENTERED : 3754059
# event appended
# ---------------------
# 188 - ENTERED : 3754064
# event appended
# ---------------------
# 189 - ENTERED : 3754065
# event appended
# ---------------------
# 190 - ENTERED : 3754173
# event appended
# ---------------------
# 191 - ENTERED : 3754175
# event appended
# ---------------------
# 192 - ENTERED : 3753973
# event appended
# ---------------------
# 193 - ENTERED : 3753975
# event appended
# ---------------------
# 194 - ENTERED : 3753976
# event appended
# ---------------------
# 195 - ENTERED : 3753977
# event appended
# ---------------------
# 196 - ENTERED : 3753980
# event appended
# ---------------------
# 197 - ENTERED : 3753981
# event appended
# ---------------------
# 198 - ENTERED : 3753982
# event appended
# ---------------------
# 199 - ENTERED : 3753986
# event appended
# ---------------------
# 200 - ENTERED : 3753988
# event appended
# ---------------------
# 201 - ENTERED : 3753989
# event appended
# ---------------------
# 202 - ENTERED : 3753990
# event appended
# ---------------------
# 203 - ENTERED : 3753991
# event appended
# ---------------------
# 204 - ENTERED : 3753992
# event appended
# ---------------------
# 205 - ENTERED : 3753994
# event appended
# ---------------------
# 206 - ENTERED : 3753997
# event appended
# ---------------------
# 207 - ENTERED : 3753998
# event appended
# ---------------------
# 208 - ENTERED : 3754002
# event appended
# ---------------------
# 209 - ENTERED : 3754004
# event appended
# ---------------------
# 210 - ENTERED : 3754005
# event appended
# ---------------------
# 211 - ENTERED : 3754009
# event appended
# ---------------------
# 212 - ENTERED : 3754012
# event appended
# ---------------------
# 213 - ENTERED : 3754016
# event appended
# ---------------------
# 214 - ENTERED : 3754018
# event appended
# ---------------------
# 215 - ENTERED : 3754019
# event appended
# ---------------------
# 216 - ENTERED : 3754021
# event appended
# ---------------------
# 217 - ENTERED : 3754022
# event appended
# ---------------------
# 218 - ENTERED : 3754024
# event appended
# ---------------------
# 219 - ENTERED : 3754026
# event appended
# ---------------------
# 220 - ENTERED : 3754027
# event appended
# ---------------------
# 221 - ENTERED : 3754030
# event appended
# ---------------------
# 222 - ENTERED : 3754031
# event appended
# ---------------------
# 223 - ENTERED : 3754032
# event appended
# ---------------------
# 224 - ENTERED : 3754033
# event appended
# ---------------------
# 225 - ENTERED : 3754035
# event appended
# ---------------------
# 226 - ENTERED : 3754036
# event appended
# ---------------------
# 227 - ENTERED : 3754061
# event appended
# ---------------------
# 228 - ENTERED : 3754062
# event appended
# ---------------------
# 229 - ENTERED : 3754063
# event appended
# ---------------------
# 230 - ENTERED : 3754069
# event appended
# ---------------------
# 231 - ENTERED : 3754070
# event appended
# ---------------------
# 232 - ENTERED : 3754071
# event appended
# ---------------------
# 233 - ENTERED : 3754075
# event appended
# ---------------------
# 234 - ENTERED : 3754080
# event appended
# ---------------------
# 235 - ENTERED : 3754081
# event appended
# ---------------------
# 236 - ENTERED : 3754084
# event appended
# ---------------------
# 237 - ENTERED : 3754086
# event appended
# ---------------------
# 238 - ENTERED : 3754087
# event appended
# ---------------------
# 239 - ENTERED : 3754088
# event appended
# ---------------------
# 240 - ENTERED : 3754089
# event appended
# ---------------------
# 241 - ENTERED : 3754092
# event appended
# ---------------------
# 242 - ENTERED : 3754094
# event appended
# ---------------------
# 243 - ENTERED : 3754095
# event appended
# ---------------------
# 244 - ENTERED : 3754100
# event appended
# ---------------------
# 245 - ENTERED : 3754101
# event appended
# ---------------------
# 246 - ENTERED : 3754103
# event appended
# ---------------------
# 247 - ENTERED : 3754108
# event appended
# ---------------------
# 248 - ENTERED : 3754110
# event appended
# ---------------------
# 249 - ENTERED : 3754111
# event appended
# ---------------------
# 250 - ENTERED : 3754114
# event appended
# ---------------------
# 251 - ENTERED : 3754116
# event appended
# ---------------------
# 252 - ENTERED : 3754118
# event appended
# ---------------------
# 253 - ENTERED : 3754120
# event appended
# ---------------------
# 254 - ENTERED : 3754121
# event appended
# ---------------------
# 255 - ENTERED : 3754122
# event appended
# ---------------------
# 256 - ENTERED : 3754123
# event appended
# ---------------------
# 257 - ENTERED : 3754124
# event appended
# ---------------------
# 258 - ENTERED : 3754125
# event appended
# ---------------------
# 259 - ENTERED : 3754127
# event appended
# ---------------------
# 260 - ENTERED : 3754132
# event appended
# ---------------------
# 261 - ENTERED : 3754134
# event appended
# ---------------------
# 262 - ENTERED : 3754137
# event appended
# ---------------------
# 263 - ENTERED : 3754139
# event appended
# ---------------------
# 264 - ENTERED : 3754140
# event appended
# ---------------------
# 265 - ENTERED : 3754142
# event appended
# ---------------------
# 266 - ENTERED : 3754144
# event appended
# ---------------------
# 267 - ENTERED : 3754147
# event appended
# ---------------------
# 268 - ENTERED : 3754149
# event appended
# ---------------------
# 269 - ENTERED : 3754151
# event appended
# ---------------------
# 270 - ENTERED : 3754152
# event appended
# ---------------------
# 271 - ENTERED : 3754154
# event appended
# ---------------------
# 272 - ENTERED : 3754155
# event appended
# ---------------------
# 273 - ENTERED : 3754158
# event appended
# ---------------------
# 274 - ENTERED : 3754159
# event appended
# ---------------------
# 275 - ENTERED : 3754161
# event appended
# ---------------------
# 276 - ENTERED : 3754163
# event appended
# ---------------------
# 277 - ENTERED : 3754164
# event appended
# ---------------------
# 278 - ENTERED : 3754165
# event appended
# ---------------------
# 279 - ENTERED : 3754168
# event appended
# ---------------------
# 280 - ENTERED : 3754170
# event appended
# ---------------------
# 281 - ENTERED : 3754172
# event appended
# ---------------------
# 282 - ENTERED : 3754176
# event appended
# ---------------------
# 283 - ENTERED : 3754177
# event appended
# ---------------------
# 284 - ENTERED : 3754179
# event appended
# ---------------------
# 285 - ENTERED : 3754181
# event appended
# ---------------------
# 286 - ENTERED : 3754183
# event appended
# ---------------------
# 287 - ENTERED : 3754184
# event appended
# ---------------------
# 288 - ENTERED : 3754187
# event appended
# ---------------------
# 289 - ENTERED : 3754191
# event appended
# ---------------------
# 290 - ENTERED : 3754192
# event appended
# ---------------------
# 291 - ENTERED : 3754195
# event appended
# ---------------------
# 292 - ENTERED : 3754196
# event appended
# ---------------------
# 293 - ENTERED : 3754199
# event appended
# ---------------------
# 294 - ENTERED : 3754200
# event appended
# ---------------------
# 295 - ENTERED : 3754201
# event appended
# ---------------------
# 296 - ENTERED : 3754202
# event appended
# ---------------------
# 297 - ENTERED : 3754206
# event appended
# ---------------------
# 298 - ENTERED : 3754207
# event appended
# ---------------------
# 299 - ENTERED : 3754209
# event appended
# ---------------------
# 300 - ENTERED : 3754210
# event appended
# ---------------------
# 301 - ENTERED : 3754214
# event appended
# ---------------------
# 302 - ENTERED : 3754215
# event appended
# ---------------------
# 303 - ENTERED : 3754216
# event appended
# ---------------------
# 304 - ENTERED : 3754220
# event appended
# ---------------------
# 305 - ENTERED : 3754224
# event appended
# ---------------------
# 306 - ENTERED : 3754225
# event appended
# ---------------------
# 307 - ENTERED : 3754227
# event appended
# ---------------------
# 308 - ENTERED : 3754228
# event appended
# ---------------------
# 309 - ENTERED : 3754229
# event appended
# ---------------------
# 310 - ENTERED : 3754231
# event appended
# ---------------------
# 311 - ENTERED : 3754232
# event appended
# ---------------------
# 312 - ENTERED : 3754236
# event appended
# ---------------------
# 313 - ENTERED : 3754239
# event appended
# ---------------------
# 314 - ENTERED : 3754241
# event appended
# ---------------------
# 315 - ENTERED : 3754242
# event appended
# ---------------------
# 316 - ENTERED : 3754243
# event appended
# ---------------------
# 317 - ENTERED : 3754244
# event appended
# ---------------------
# 318 - ENTERED : 3754249
# event appended
# ---------------------
# 319 - ENTERED : 3754250
# event appended
# ---------------------
# 320 - ENTERED : 3754251
# event appended
# ---------------------
# 321 - ENTERED : 3754252
# event appended
# ---------------------
# 322 - ENTERED : 3754253
# event appended
# ---------------------
# 323 - ENTERED : 3754260
# event appended
# ---------------------
# 324 - ENTERED : 3754261
# event appended
# ---------------------
# 325 - ENTERED : 3754262
# event appended
# ---------------------
# 326 - ENTERED : 3754264
# event appended
# ---------------------
# 327 - ENTERED : 3754295
# event appended
# ---------------------
# 328 - ENTERED : 3754271
# event appended
# ---------------------
# 329 - ENTERED : 3754272
# event appended
# ---------------------
# 330 - ENTERED : 3754274
# event appended
# ---------------------
# 331 - ENTERED : 3754275
# event appended
# ---------------------
# 332 - ENTERED : 3754277
# event appended
# ---------------------
# 333 - ENTERED : 3754280
# event appended
# ---------------------
# 334 - ENTERED : 3754281
# event appended
# ---------------------
# 335 - ENTERED : 3754282
# event appended
# ---------------------
# 336 - ENTERED : 3754284
# event appended
# ---------------------
# 337 - ENTERED : 3754289
# event appended
# ---------------------
# 338 - ENTERED : 3754290
# event appended
# ---------------------
# 339 - ENTERED : 3754292
# event appended
# ---------------------
# 340 - ENTERED : 3754294
# event appended
# ---------------------
# 341 - ENTERED : 3754248
# event appended
# ---------------------
# 342 - ENTERED : 3754299
# event appended
# ---------------------
# 343 - ENTERED : 3754303
# event appended
# ---------------------
# 344 - ENTERED : 3754305
# event appended
# ---------------------
# 345 - ENTERED : 3754306
# event appended
# ---------------------
# 346 - ENTERED : 3754307
# event appended
# ---------------------
# 347 - ENTERED : 3754308
# event appended
# ---------------------
# 348 - ENTERED : 3754310
# event appended
# ---------------------
# 349 - ENTERED : 3754313
# event appended
# ---------------------
# 350 - ENTERED : 3754314
# event appended
# ---------------------
# 351 - ENTERED : 3754316
# event appended
# ---------------------
# 352 - ENTERED : 3754317
# event appended
# ---------------------
# 353 - ENTERED : 3754318
# event appended
# ---------------------
# 354 - ENTERED : 3754319
# event appended
# ---------------------
# 355 - ENTERED : 3754320
# event appended
# ---------------------
# 356 - ENTERED : 3754321
# event appended
# ---------------------
# 357 - ENTERED : 3754322
# event appended
# ---------------------
# 358 - ENTERED : 3754324
# event appended
# ---------------------
# 359 - ENTERED : 3754326
# event appended
# ---------------------
# 360 - ENTERED : 3754327
# event appended
# ---------------------
# 361 - ENTERED : 3754331
# event appended
# ---------------------
# 362 - ENTERED : 3754332
# event appended
# ---------------------
# 363 - ENTERED : 3754333
# event appended
# ---------------------
# 364 - ENTERED : 3754334
# event appended
# ---------------------
# 365 - ENTERED : 3754338
# event appended
# ---------------------
# 366 - ENTERED : 3754340
# event appended
# ---------------------
# 367 - ENTERED : 3754341
# event appended
# ---------------------
# 368 - ENTERED : 3754342
# event appended
# ---------------------
# 369 - ENTERED : 3754345
# event appended
# ---------------------
# 370 - ENTERED : 3754346
# event appended
# ---------------------
# 371 - ENTERED : 3754348
# event appended
# ---------------------
# 372 - ENTERED : 3754349
# event appended
# ---------------------
# 373 - ENTERED : 3754350
# event appended
# ---------------------
# 374 - ENTERED : 3754258
# event appended
# ---------------------
# 375 - ENTERED : 3754020
# event appended
# ---------------------
# 376 - ENTERED : 3754267
# event appended
# ---------------------
# 377 - ENTERED : 3754141
# event appended
# ---------------------
# 378 - ENTERED : 3754128
# event appended
# ---------------------
# 379 - ENTERED : 3754078
# event appended
# ---------------------
# appending complete
# Concatenation done
# CPU times: user 1min 50s, sys: 17.7 s, total: 2min 8s
# Wall time: 6min
# 1313783

# %%
# %%time
# SELECTs events from previously recorded event data in a staging table
# connect & read
conn = sqlite3.connect(db_path)
# the events of matches
df_event = pd.read_sql_query(
    '''SELECT * 
    FROM event_stg;
    ''', conn)
print(len(df_event))
# the lineups & match data
with open('data/selected_matches.sql') as inserts:
    lineup_q = inserts.read()
lineups = pd.read_sql_query(lineup_q, conn)

# close the connection
conn.close()
# merge the lineups with
df_event = df_event.merge(lineups,on=["player_id","match_id"],how="left")
print(print(df_event.info()))
print(len(df_event))
df_event.head()
# Out:
# 1313783
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313783 entries, 0 to 1313782
# Columns: 146 entries, id to country_name_lineup
# dtypes: float64(78), int64(10), object(58)
# memory usage: 1.4+ GB
# None
# None
# 1313783
# CPU times: user 17.6 s, sys: 1.09 s, total: 18.7 s
# Wall time: 18.8 s
#                                      id  index  period        timestamp  \
# 0  9153e9f4-f69c-4e04-8f64-505592e212cd      1       1  00:00:00.000000
# 1  3fbcf4e7-94d1-485a-be85-fd26a6af0318      2       1  00:00:00.000000
# 2  06a9a4dc-d9c9-40f6-bd89-437ba7fe682d      3       1  00:00:00.000000
# 3  100362ee-9311-4187-bd8a-0201d9db2565      4       1  00:00:00.000000
# 4  2ca23eea-a984-47e4-8243-8f00880ad1c9      5       1  00:00:01.000000
#
#    minute  second  possession  duration  match_id  type_id  ...  \
# 0       0       0           1  0.000000   3754058       35  ...
# 1       0       0           1  0.000000   3754058       35  ...
# 2       0       0           1  0.000000   3754058       18  ...
# 3       0       0           1  0.000000   3754058       18  ...
# 4       0       1           2  0.308263   3754058       30  ...
#
#      referee_name  referee_country_id referee_country_name  player_name_y  \
# 0             NaN                 NaN                  NaN            NaN
# 1             NaN                 NaN                  NaN            NaN
# 2             NaN                 NaN                  NaN            NaN
# 3             NaN                 NaN                  NaN            NaN
# 4  Andre Marriner                68.0              England    Dan Gosling
#
#   player_nickname  jersey_number team_id_y      team_name_y  country_id  \
# 0             NaN            NaN       NaN              NaN         NaN
# 1             NaN            NaN       NaN              NaN         NaN
# 2             NaN            NaN       NaN              NaN         NaN
# 3             NaN            NaN       NaN              NaN         NaN
# 4     Dan Gosling            4.0      28.0  AFC Bournemouth        68.0
#
#   country_name_lineup
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4             England
#
# [5 rows x 146 columns]

# %% [markdown]
# ### Following graph will be defined as a method inside vizFunc.py

# %%
from scipy.stats import t
from scipy import stats
pitch = VerticalPitch(pad_bottom=0.5,
        half=True,
        goal_type='box',
        goal_alpha=0.8,
        line_zorder = 2,
        line_color='#cfcfcf',
        pitch_color = "#131722",
        pitch_type='statsbomb')

fig, axs = pitch.grid(nrows=3,
                        ncols=2,
                        grid_width=0.88,
                        left=0.025,
                        figheight=30,
                        endnote_height=0.05,
                        endnote_space=0,
                        axis=False,
                        title_space=0.01,
                        title_height=0.06,
                        grid_height=0.8,
                        space = 0.03)

analyzer = footyviz(df_event, pitch)
conversion_rates = analyzer.data[analyzer.data['type_name'] == 'Shot'].groupby('player_id')['outcome_name'].apply(lambda x: (x == 'Goal').mean())
conversion_rates = conversion_rates[analyzer.data[analyzer.data['type_name'] == 'Shot'].groupby('player_id')['outcome_name'].count() > 10]

analyzer.navigate(type_name='Shot',team_name_x='Leicester City')
# understand axes' grids and define them in variables.
grid_row_len = len(axs["pitch"]) # define grid's row count
grid_col_len = len(axs["pitch"][0]) # define grid's column count
grid_size = grid_row_len * grid_col_len # define grid size

fig.set_facecolor(analyzer.backgroundColor)

# get most shots based on grid size to fill all grids with players. defining grids will determine how many players it'll visualize
most_shots = analyzer.data.groupby("player_id").agg({"type_name":"count"}).sort_values(by="type_name",ascending=False).head(grid_size).index.tolist()
playerNameFm = FontManager(url=config["fonts"]["rubik"])
captionFm = FontManager(url=config["fonts"]["bebas_neue"])
nameTagFm = FontManager(url=config["fonts"]["roboto_regular"])


for i in [((index // grid_col_len), (index % grid_col_len), value) for index, value in enumerate(most_shots)]:
    playerData = analyzer.data[analyzer.data.player_id == i[2]]
    playerNick = playerData.player_nickname.iloc[0]
    teamName = playerData.team_name_x.iloc[0]
    bs = pitch.bin_statistic(playerData.x, playerData.y, bins=(12, 8))
    heatmap = pitch.heatmap(bs, 
                            edgecolors='#122c3d',
                            ax=axs["pitch"][i[0]][i[1]],
                            cmap=get_config_cmap("pearl_earring",n=100))
    goals = playerData[playerData.outcome_name == "Goal"]
    nogoals = playerData[playerData.outcome_name != "Goal"]
    conv_rate = len(goals) / len(playerData)
    shot_count = len(playerData)
    goals_scatty = pitch.scatter(goals.x, goals.y, s=goals.shot_statsbomb_xg * 700, zorder =3,
                        ec='black', color='#4EFF83',ax=axs["pitch"][i[0]][i[1]])
    others_scatty = pitch.scatter(nogoals.x, nogoals.y, s=nogoals.shot_statsbomb_xg * 700,
                        ec='black', color='#ba495c',ax=axs["pitch"][i[0]][i[1]])
    density_ax = axs["pitch"][i[0]][i[1]].inset_axes([0.35, 0.05, 0.3, 0.2])  # [x, y, width, height]
    density_ax.set_axis_off()
    kde_data = sns.kdeplot(conversion_rates,color="#EBFF01", cut=0,ax=density_ax).get_lines()[0].get_data()
    x_values, y_values = kde_data
    sns.kdeplot(conversion_rates, fill=True, color="#EBFF01",cut=0,ax=density_ax)
    density_ax.fill_between(x_values, 0, y_values, where=(x_values > conv_rate), color='red', alpha=0.5)
    density_ax.set_facecolor('none')
    ax_text(40, 85, 
            f'''{playerNick}''',
        ax=axs["pitch"][i[0]][i[1]],
        fontsize=40,
        va='center',
        ha='center',
        color = pitch.line_color,
        weight='bold',
        fontproperties=playerNameFm.prop
        ,zorder = 5)
    ax_text(40, 80, 
            f'''Conversion: <{conv_rate:.0%}>  [{len(playerData)} shots]''',
        ax=axs["pitch"][i[0]][i[1]],
        fontsize=30,
        va='center',
        ha='center',
        color = pitch.line_color,
        weight='bold',
        fontproperties=captionFm.prop
        , highlight_textprops=[{"color": '#EBFF01'}]
        ,zorder = 5)

ax_text(0, 0.5, 
        f'''<Shots>, <Goals> and <Conversion>''',
    ax=axs["title"],
    fontsize=75,
    va='bottom',
    ha='left',
    color = pitch.line_color,
    weight='bold',
    fontproperties=captionFm.prop
    , highlight_textprops=[{"color": '#BA495C'},{"color": '#4EFF83'},{"color": '#EBFF01'}]
    ,zorder = 5)

ax_text(0, 0.24,
        f'''{teamName}''',
    ax=axs["title"],
    fontsize=50,
    va='center',
    ha='left',
    color = pitch.line_color,
    weight='bold',
    fontproperties=captionFm.prop
    ,zorder = 5)

ax_text(0, 0, 
        f'''{analyzer.seasonNameList[0]}''',
    ax=axs["title"],
    fontsize=50,
    va='top',
    ha='left',
    color = pitch.line_color,
    weight='bold',
    fontproperties=captionFm.prop
    ,zorder = 5)

axs['endnote'].text(1, 0.4, '@false9ry',color="#4393c4" ,
                    va='center', ha='right', fontsize=20,
                    fontproperties=playerNameFm.prop)
axs['endnote'].text(1, 0.7, 'VIZ BY: MURAT SEYHAN', color=pitch.line_color,
                    va='center', ha='right', fontsize=20,
                    fontproperties=playerNameFm.prop)
axs['endnote'].text(0, 0.7, 'Conversion rate for >10 shot takers', color=pitch.line_color,
                    va='center', ha='left', fontsize=25,
                    fontproperties=nameTagFm.prop)
